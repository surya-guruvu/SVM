# %% [markdown]
# # Linear Multi-class Classification using SVM using all feature vectors

# %%
from libsvm.svmutil import *
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt
import cvxopt
from cvxopt import matrix,solvers

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/train_set.csv',header = None,prefix='Column')

# %%
df1=df.Column25
label=np.array(df1)
label_train=label[0:6000]
label_test=label[6000:8000]

# %%
df=df.iloc[:,0:25:1]
data = df.values #To convert data frame into numpy array
train_data=data[0:6000]
test_data=data[6000:8000]

# %%
prob = svm_problem(label_train, train_data)

Accuracy=[]
max=0
j=0
j1=0
for k in range(-10,10):
    for i in range(-10,10):
        param = svm_parameter('-t 2 -g {} -c {} -b 0'.format(2**k,2**i))
        m = svm_train(prob, param)
        p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
        Accuracy.append(p_acc[0])
        if(max<p_acc[0]):
            max=p_acc[0]
            j=i
            j1=k
    

print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
print('Value of coarse log2(gamma), for maximum accuracy: {}'.format(j1))
# Out:
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 36.85% (737/2000) (classification)
# Accuracy = 64.9% (1298/2000) (classification)
# Accuracy = 80.95% (1619/2000) (classification)
# Accuracy = 84.85% (1697/2000) (classification)
# Accuracy = 87.65% (1753/2000) (classification)
# Accuracy = 89.6% (1792/2000) (classification)
# Accuracy = 90.6% (1812/2000) (classification)
# Accuracy = 91.5% (1830/2000) (classification)
# Accuracy = 91.85% (1837/2000) (classification)
# Accuracy = 92.35% (1847/2000) (classification)
# Accuracy = 92.9% (1858/2000) (classification)
# Accuracy = 93.55% (1871/2000) (classification)
# Accuracy = 93.85% (1877/2000) (classification)
# Accuracy = 94.45% (1889/2000) (classification)
# Accuracy = 94.15% (1883/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 33.75% (675/2000) (classification)
# Accuracy = 63.9% (1278/2000) (classification)
# Accuracy = 80.9% (1618/2000) (classification)
# Accuracy = 85.1% (1702/2000) (classification)
# Accuracy = 87.75% (1755/2000) (classification)
# Accuracy = 89.7% (1794/2000) (classification)
# Accuracy = 90.85% (1817/2000) (classification)
# Accuracy = 91.65% (1833/2000) (classification)
# Accuracy = 92.4% (1848/2000) (classification)
# Accuracy = 93.05% (1861/2000) (classification)
# Accuracy = 93.3% (1866/2000) (classification)
# Accuracy = 94.15% (1883/2000) (classification)
# Accuracy = 94.4% (1888/2000) (classification)
# Accuracy = 94.55% (1891/2000) (classification)
# Accuracy = 94.7% (1894/2000) (classification)
# Accuracy = 94.7% (1894/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 27.1% (542/2000) (classification)
# Accuracy = 59.35% (1187/2000) (classification)
# Accuracy = 80.2% (1604/2000) (classification)
# Accuracy = 85.35% (1707/2000) (classification)
# Accuracy = 88% (1760/2000) (classification)
# Accuracy = 90.25% (1805/2000) (classification)
# Accuracy = 91.15% (1823/2000) (classification)
# Accuracy = 92.35% (1847/2000) (classification)
# Accuracy = 93.15% (1863/2000) (classification)
# Accuracy = 93.65% (1873/2000) (classification)
# Accuracy = 94.25% (1885/2000) (classification)
# Accuracy = 94.55% (1891/2000) (classification)
# Accuracy = 94.8% (1896/2000) (classification)
# Accuracy = 94.85% (1897/2000) (classification)
# Accuracy = 94.75% (1895/2000) (classification)
# Accuracy = 95% (1900/2000) (classification)
# Accuracy = 95% (1900/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 14% (280/2000) (classification)
# Accuracy = 51.4% (1028/2000) (classification)
# Accuracy = 76.85% (1537/2000) (classification)
# Accuracy = 85.15% (1703/2000) (classification)
# Accuracy = 88.35% (1767/2000) (classification)
# Accuracy = 90.45% (1809/2000) (classification)
# Accuracy = 91.6% (1832/2000) (classification)
# Accuracy = 92.8% (1856/2000) (classification)
# Accuracy = 93.9% (1878/2000) (classification)
# Accuracy = 94.4% (1888/2000) (classification)
# Accuracy = 94.85% (1897/2000) (classification)
# Accuracy = 95.1% (1902/2000) (classification)
# Accuracy = 95.4% (1908/2000) (classification)
# Accuracy = 95.6% (1912/2000) (classification)
# Accuracy = 95.45% (1909/2000) (classification)
# Accuracy = 95.55% (1911/2000) (classification)
# Accuracy = 95.55% (1911/2000) (classification)
# Accuracy = 95.5% (1910/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 30.95% (619/2000) (classification)
# Accuracy = 64.7% (1294/2000) (classification)
# Accuracy = 83.95% (1679/2000) (classification)
# Accuracy = 88.5% (1770/2000) (classification)
# Accuracy = 90.55% (1811/2000) (classification)
# Accuracy = 92.55% (1851/2000) (classification)
# Accuracy = 93.7% (1874/2000) (classification)
# Accuracy = 94.65% (1893/2000) (classification)
# Accuracy = 94.95% (1899/2000) (classification)
# Accuracy = 95.4% (1908/2000) (classification)
# Accuracy = 95.8% (1916/2000) (classification)
# Accuracy = 95.95% (1919/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 95.95% (1919/2000) (classification)
# Accuracy = 96.05% (1921/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 29.15% (583/2000) (classification)
# Accuracy = 63.05% (1261/2000) (classification)
# Accuracy = 86.5% (1730/2000) (classification)
# Accuracy = 90.65% (1813/2000) (classification)
# Accuracy = 92.65% (1853/2000) (classification)
# Accuracy = 94.1% (1882/2000) (classification)
# Accuracy = 94.7% (1894/2000) (classification)
# Accuracy = 95.35% (1907/2000) (classification)
# Accuracy = 95.55% (1911/2000) (classification)
# Accuracy = 96.15% (1923/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 96.2% (1924/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 14.5% (290/2000) (classification)
# Accuracy = 29.5% (590/2000) (classification)
# Accuracy = 64.55% (1291/2000) (classification)
# Accuracy = 88.25% (1765/2000) (classification)
# Accuracy = 92% (1840/2000) (classification)
# Accuracy = 93.85% (1877/2000) (classification)
# Accuracy = 94.9% (1898/2000) (classification)
# Accuracy = 96.2% (1924/2000) (classification)
# Accuracy = 96.4% (1928/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 16.65% (333/2000) (classification)
# Accuracy = 18.4% (368/2000) (classification)
# Accuracy = 30.15% (603/2000) (classification)
# Accuracy = 59.05% (1181/2000) (classification)
# Accuracy = 84.5% (1690/2000) (classification)
# Accuracy = 92.1% (1842/2000) (classification)
# Accuracy = 94.9% (1898/2000) (classification)
# Accuracy = 95.6% (1912/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 11.55% (231/2000) (classification)
# Accuracy = 18.1% (362/2000) (classification)
# Accuracy = 19.45% (389/2000) (classification)
# Accuracy = 24.85% (497/2000) (classification)
# Accuracy = 38.9% (778/2000) (classification)
# Accuracy = 67.6% (1352/2000) (classification)
# Accuracy = 88.55% (1771/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 88.9% (1778/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 18.65% (373/2000) (classification)
# Accuracy = 17.25% (345/2000) (classification)
# Accuracy = 21.8% (436/2000) (classification)
# Accuracy = 23.2% (464/2000) (classification)
# Accuracy = 54.25% (1085/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 57.95% (1159/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 16.4% (328/2000) (classification)
# Accuracy = 17.25% (345/2000) (classification)
# Accuracy = 27.6% (552/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 30.35% (607/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.8% (216/2000) (classification)
# Accuracy = 17.35% (347/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 17.9% (358/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.85% (217/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Accuracy = 10.75% (215/2000) (classification)
# Value of coarse log2(c), for maximum accuracy: 2
# Value of coarse log2(gamma), for maximum accuracy: -4
# The percentage of predicted values

# %%
prob = svm_problem(label_train, train_data)

Accuracy=[]
max=0
j=0
j1=0
k=-4
while(k<-3):
    i=2
    while(i<3):
        param = svm_parameter('-t 2 -g {} -c {} -b 0'.format(2**k,2**i))
        m = svm_train(prob, param)
        p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
        Accuracy.append(p_acc[0])
        if(max<p_acc[0]):
            max=p_acc[0]
            j=i
            j1=k
        i+=1
    k+=0.01
    

print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
print('Value of coarse log2(gamma), for maximum accuracy: {}'.format(j1))
print('The percentage of predicted values is equal to {} %'.format(max))
# Out:
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.65% (1933/2000) (classification)
# Accuracy = 96.7% (1934/2000) (classification)
# Accuracy = 96.7% (1934/2000) (classification)
# Accuracy = 96.7% (1934/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.75% (1935/2000) (classification)
# Accuracy = 96.7% (1934/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.6% (1932/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.55% (1931/2000) (classification)
# Accuracy = 96.5% (1930/2000) (classification)
# Accuracy = 96.5% (1930/2000) (classification)
# Accuracy = 96.5% (1930/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.45% (1929/2000) (classification)
# Accuracy = 96.4% (1928/2000) (classification)
# Accuracy = 96.4% (1928/2000) (classification)
# Accuracy = 96.4% (1928/2000) (classification)
# Accuracy = 96.4% (1928/2000) (classification)
# Accuracy = 96.4% (1928/2000) (classification)
# Accuracy = 96.4% (1928/2000) (classification)
# Accuracy = 96.3% (1926/2000) (classification)
# Accuracy = 96.2% (1924/2000) (classification)
# Accuracy = 96.2% (1924/2000) (classification)
# Accuracy = 96.2% (1924/2000) (classification)
# Accuracy = 96.2% (1924/2000) (classification)
# Accuracy = 96.25% (1925/2000) (classification)
# Accuracy = 96.25% (1925/2000) (classification)
# Accuracy = 96.25% (1925/2000) (classification)
# Accuracy = 96.25% (1925/2000) (classification)
# Accuracy = 96.25% (1925/2000) (classification)
# Accuracy = 96.15% (1923/2000) (classification)
# Accuracy = 96.15% (1923/2000) (classification)
# Accuracy = 96.15% (1923/2000) (classification)
# Accuracy = 96.1% (1922/2000) (classification)
# Accuracy = 96.1% (1922/2000) (classification)
# Accuracy = 96.1% (1922/2000) (classification)
# Accuracy = 96.1% (1922/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 96% (1920/2000) (classification)
# Accuracy = 95.95% (1919/2000) (classification)
# Accuracy = 95.9% (1918/2000) (classification)
# Accuracy = 95.85% (1917/2000) (classification)
# Accuracy = 95.75% (1915/2000) (classification)
# Accuracy = 95.75% (1915/2000) (classification)
# Accuracy = 95.75% (1915/2000) (classification)
# Accuracy = 95.7% (1914/2000) (classification)
# Value of coarse log2(c), for maximum accuracy: 2
# Value of coarse log2(gamma), for maximum accuracy: -3.950000000000001
# The percentage of predicted values is equal to 96.75 %

# %%
df1 = pd.read_csv('C:/Users/surya/Downloads/409-Ass2/test_set.csv',header = None,prefix='Column')

# %%
label_dummy=np.ones(2000)

# %%
df=df1.iloc[:,0:25:1]
data1 = df.values #To convert data frame into numpy array

# %%
prob = svm_problem(label_train, train_data)
param = svm_parameter('-t 2 -g {} -c {} -b 0'.format(2**(-3.95),2**(2)))
m = svm_train(prob, param)
p_label, p_acc, p_val = svm_predict(label_dummy, data1, m)
# Out:
# Accuracy = 10.45% (209/2000) (classification)

# %%
p_label=np.array(p_label)
print(p_label)
# Out:
# [1. 1. 1. ... 0. 2. 7.]

# %%
arr=np.arange(2001)[1:2001]

arr = arr.astype('str')
print(arr)
# Out:
# ['1' '2' '3' ... '1998' '1999' '2000']

# %%
L={"Id":arr,"Class":p_label}
df_out=pd.DataFrame(L)
print(df_out)
# Out:
#         Id  Class
# 0        1    1.0
# 1        2    1.0
# 2        3    1.0
# 3        4    6.0
# 4        5    4.0
# ...    ...    ...
# 1995  1996    8.0
# 1996  1997    8.0
# 1997  1998    0.0
# 1998  1999    2.0
# 1999  2000    7.0
#
# [2000 rows x 2 columns]

# %%
with open('foo3.csv','w+') as f:
    f.write('Id,Class\n')
    for i in range(p_label.shape[0]):
        if (i+1<1000):
            f.write('{},{:d}\n'.format(str(i+1),int(p_label[i])))
        else:
            f.write('\"{:01d},{:03d}\",{:d}\n'.format((i+1)//1000,(i+1)%1000,int(p_label[i])))
            #f.write('\"{:01d},{:03d}\",{:d}\n'.format((i+1)//1000, (i+1)%1000, int(p_label[I])))
