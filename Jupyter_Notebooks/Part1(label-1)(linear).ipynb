# %% [markdown]
# # Linear Binary Classification using SVM using all feature vectors

# %%
from libsvm.svmutil import *
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt
import cvxopt
from cvxopt import matrix,solvers

# %% [markdown]
# ## Reading CSV file

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[0:2] # labels for Binary Clasification

# %%
df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]

# %% [markdown]
# # Binary classification using all the feature vectors
# ## Labels for binary classification
# Labels used are 2.0 and 5.0

# %%
df3=df1.Column25
label=np.array(df3)
label_train=label[0:177]
label_test=label[177:577]

# %% [markdown]
# ## Data for Binary classification

# %%
df1=df1.iloc[:,0:25:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:177]
test_data=data[177:577]

# %% [markdown]
# ## Training SVM

# %%
prob = svm_problem(label_train, train_data)

c=[]
Accuracy=[]
max=0
j=0
for i in range(-20,20):
    c.append(i)
    param = svm_parameter('-t 0 -c {} -b 0'.format(2**i))
    m = svm_train(prob, param)
    p_label, p_acc, p_val = svm_predict(label_train, train_data, m) 
    Accuracy.append(p_acc[0])

    if(max<p_acc[0]):
        max=p_acc[0]
        j=i
    
plt.plot(c,Accuracy,label='train')

c=[]
Accuracy=[]
max=0
j=0
for i in range(-20,40):
    c.append(i)
    param = svm_parameter('-t 0 -c {} -b 0'.format(2**i))
    m = svm_train(prob, param)
    p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
    Accuracy.append(p_acc[0])

    if(max<p_acc[0]):
        max=p_acc[0]
        j=i
    
plt.plot(c,Accuracy,label='test')
plt.show()
print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
# Out:
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 52.5424% (93/177) (classification)
# Accuracy = 80.791% (143/177) (classification)
# Accuracy = 96.0452% (170/177) (classification)
# Accuracy = 94.9153% (168/177) (classification)
# Accuracy = 96.0452% (170/177) (classification)
# Accuracy = 97.7401% (173/177) (classification)
# Accuracy = 97.7401% (173/177) (classification)
# Accuracy = 97.1751% (172/177) (classification)
# Accuracy = 97.7401% (173/177) (classification)
# Accuracy = 99.435% (176/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 100% (177/177) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 82% (328/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Value of coarse log2(c), for maximum accuracy: -5

# %%
c=[]
Accuracy=[]
max=0
j=0
i=-6
while(i<-4):
    c.append(i)
    param = svm_parameter('-t 0 -c {} -b 0'.format(2**i))
    m = svm_train(prob, param)
#svm_type = m.get_svm_type()
    p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
    Accuracy.append(p_acc[0])
    #print(svm_type)
    #print(m)
    if(max<p_acc[0]):
        max=p_acc[0]
        j=i
    i+=0.001
plt.plot(c,Accuracy)
plt.show()
print('Value of fine log2(c), for maximum accuracy: {}'.format(j))
print('The percentage of predicted values: {}'.format(max))
# Out:
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# ...
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Value of fine log2(c), for maximum accuracy: -5.622999999999874
# The percentage of predicted values: 96.0

# %% [markdown]
# # Solving using CVXOPT using all feature vectors

# %% [markdown]
# ## Reading CSV file

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[0:2] # labels for Binary Clasification

# %%
df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]

# %% [markdown]
# ## Create label array and Converting them into -1, 1
# Labels used are 2.0 and 5.0

# %%
df3=df1.Column25
label=np.array(df3)

for i in range(len(label)):
    if(label[i]==2.0):
        label[i]=1.0
    else:
        label[i]=-1.0
        
label_train=label[0:177]
label_test=label[177:577]

# %%
df1=df1.iloc[:,0:25:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:177]
test_data=data[177:577]

N=len(label_train)
X=train_data
y=label_train

K = np.zeros((N,N))

# Generating Kernel Function (Gram-Matrix)
for i in range(N):
    for j in range(N):
        K[i,j] = np.dot(X[i], X[j])
        
# Generating P and q
P=cvxopt.matrix(np.outer(y,y) * K)
q = cvxopt.matrix(np.ones(N) * -1)


C=2**(-5.622999999999874)

#Generating conditions (i.e., o<=lambd_i<=c)
G1 = np.diag(np.ones(N) * -1)
G2 = np.identity(N)
G = cvxopt.matrix(np.vstack((G1, G2)))

h1 = np.zeros(N)
h2 = np.ones(N) * C
h = cvxopt.matrix(np.hstack((h1, h2)))


#Generating conditions (i.e., sigma())
A=cvxopt.matrix(y, (1,N))
b = cvxopt.matrix(0.0)

solution = cvxopt.solvers.qp(P, q, G, h,A,b)

a = np.ravel(solution['x'])
sv= a>1e-4
sv_index = np.arange(len(a))[sv]
sv_lambda= a[sv]  # Represent lambdas of all support vectors
sv_fea= X[sv]     # Represent all support vectors
sv_label = y[sv]


# Refer SVM.pdf for more clarity
#Validation

for n in range(len(sv_lambda)):
    b += sv_label[n]
    b -= np.sum(sv_lambda * sv_label * K[sv_index[n],sv])
b /= len(sv_lambda)


y_predict = np.zeros(len(test_data))
for i in range(len(test_data)):
    s = 0
    for a, sv_y, sv in zip(sv_lambda, sv_label, sv_fea):
        s += a * sv_y * np.dot(test_data[i], sv)
    y_predict[i] = s
y_predict=np.array(y_predict)+b


y_predict=np.sign(y_predict)

label_test=np.array(label_test)

Accuracy_table=np.ravel(label_test==y_predict)

count=0
for i in range(len(label_test)):
    if(Accuracy_table[i]==True):
        count+=1
        
print('No of Samples for which output is predicted correctly: {}'.format(count/4))
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -1.5924e+01 -6.8657e+00  1e+03  3e+01  1e-14
#  1: -8.5292e-01 -6.7493e+00  2e+01  5e-01  9e-15
#  2: -5.3767e-01 -3.6789e+00  4e+00  5e-02  1e-15
#  3: -5.0255e-01 -9.4788e-01  5e-01  5e-03  1e-15
#  4: -6.0814e-01 -7.2676e-01  1e-01  1e-03  7e-16
#  5: -6.4346e-01 -6.7233e-01  3e-02  1e-04  4e-16
#  6: -6.5250e-01 -6.5921e-01  7e-03  3e-05  5e-16
#  7: -6.5503e-01 -6.5559e-01  6e-04  1e-06  5e-16
#  8: -6.5527e-01 -6.5529e-01  2e-05  4e-08  5e-16
#  9: -6.5528e-01 -6.5528e-01  7e-07  7e-10  5e-16
# Optimal solution found.
# No of Samples for which output is predicted correctly: 95.75
