# %% [markdown]
# # Using LIBSVM

# %%
from libsvm.svmutil import *
import numpy as np
from numpy import linalg
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt
import cvxopt
from cvxopt import matrix,solvers

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[5:7] # labels for Binary Clasification

df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]

df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]
df3=df1.Column25
label=np.array(df3)
print(len(label))
label_train=label[0:180]
label_test=label[180:580]
df1=df1.iloc[:,0:25:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:180]
test_data=data[180:580]
# Out:
# 580

# %%
prob = svm_problem(label_train, train_data)

Accuracy=[]
max=0
j=0
j1=0
for k in range(-10,10):
    for i in range(-10,10):
        param = svm_parameter('-t 2 -g {} -c {} -b 0'.format(2**k,2**i))
        m = svm_train(prob, param)
        p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
        Accuracy.append(p_acc[0])
        if(max<p_acc[0]):
            max=p_acc[0]
            j=i
            j1=k
    

print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
print('Value of coarse log2(gamma), for maximum accuracy: {}'.format(j1))
print('The percentage of predicted values')
# Out:
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 77% (308/400) (classification)
# Accuracy = 89.25% (357/400) (classification)
# Accuracy = 92% (368/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 91.5% (366/400) (classification)
# Accuracy = 92.25% (369/400) (classification)
# Accuracy = 92% (368/400) (classification)
# Accuracy = 90.75% (363/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 75.75% (303/400) (classification)
# Accuracy = 88.5% (354/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 90.5% (362/400) (classification)
# Accuracy = 88.5% (354/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 68.5% (274/400) (classification)
# Accuracy = 88% (352/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 89.25% (357/400) (classification)
# Accuracy = 90.25% (361/400) (classification)
# Accuracy = 90.5% (362/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 55.75% (223/400) (classification)
# Accuracy = 85.25% (341/400) (classification)
# Accuracy = 91.75% (367/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 91.75% (367/400) (classification)
# Accuracy = 90.25% (361/400) (classification)
# Accuracy = 91% (364/400) (classification)
# Accuracy = 91% (364/400) (classification)
# Accuracy = 91% (364/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 78.75% (315/400) (classification)
# Accuracy = 91.75% (367/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 91.5% (366/400) (classification)
# Accuracy = 91.5% (366/400) (classification)
# Accuracy = 91.5% (366/400) (classification)
# Accuracy = 91.5% (366/400) (classification)
# Accuracy = 91.5% (366/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 78.25% (313/400) (classification)
# Accuracy = 91.25% (365/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 53.5% (214/400) (classification)
# Accuracy = 85.25% (341/400) (classification)
# Accuracy = 91.75% (367/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 51.25% (205/400) (classification)
# Accuracy = 77.25% (309/400) (classification)
# Accuracy = 85% (340/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 86% (344/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 50% (200/400) (classification)
# Accuracy = 72.5% (290/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 74.25% (297/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 51.5% (206/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 53.75% (215/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Value of coarse log2(c), for maximum accuracy: 3
# Value of coarse log2(gamma), for maximum accuracy: -7
# The percentage of predicted values

# %%
prob = svm_problem(label_train, train_data)

Accuracy=[]
max=0
j=0
j1=0
k=-8
while(k<-6):
    i=1
    while(i<3):
        param = svm_parameter('-t 2 -g {} -c {} -b 0'.format(2**k,2**i))
        m = svm_train(prob, param)
        p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
        Accuracy.append(p_acc[0])
        if(max<p_acc[0]):
            max=p_acc[0]
            j=i
            j1=k
        i+=0.1
    k+=0.1
    

print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
print('Value of coarse log2(gamma), for maximum accuracy: {}'.format(j1))
print('The percentage of predicted values is equal to {} %'.format(max))
# Out:
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.25% (369/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.25% (369/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.25% (369/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.25% (369/400) (classification)
# Accuracy = 92.25% (369/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 92.75% (371/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93% (372/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.25% (373/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 93.75% (375/400) (classification)
# Value of coarse log2(c), for maximum accuracy: 2.8000000000000016
# Value of coarse log2(gamma), for maximum accuracy: -6.800000000000004
# The percentage of predicted values is equal to 94.25 %

# %% [markdown]
# # Using CVXOPT

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[5:7] # labels for Binary Clasification

# %%
df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]

# %%
df3=df1.Column25
label=np.array(df3)

for i in range(len(label)):
    if(label[i]==2.0):
        label[i]=1.0
    else:
        label[i]=-1.0
        
label_train=label[0:177]
label_test=label[177:577]

# %%
df1=df1.iloc[:,0:25:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:177]
test_data=data[177:577]

N=len(label_train)
X=train_data
y=label_train

K = np.zeros((N,N))

gamma=1/(2**6.8)
C=2**(2.8)

# Generating Kernel Function (Gram-Matrix)
for i in range(N):
    for j in range(N):
        K[i,j] = np.exp((-linalg.norm(X[i]-X[j])**2)*gamma) 
        
# Generating P and q
P=cvxopt.matrix(np.outer(y,y) * K)
q = cvxopt.matrix(np.ones(N) * -1)




#Generating conditions (i.e., o<=lambd_i<=c)
G1 = np.diag(np.ones(N) * -1)
G2 = np.identity(N)
G = cvxopt.matrix(np.vstack((G1, G2)))

h1 = np.zeros(N)
h2 = np.ones(N) * C
h = cvxopt.matrix(np.hstack((h1, h2)))


#Generating conditions (i.e., sigma())
A=cvxopt.matrix(y, (1,N))
b = cvxopt.matrix(0.0)

solution = cvxopt.solvers.qp(P, q, G, h,A,b)

a = np.ravel(solution['x'])
sv= a>1e-4
sv_index = np.arange(len(a))[sv]
sv_lambda= a[sv]  # Represent lambdas of all support vectors
sv_fea= X[sv]     # Represent all support vectors
sv_label = y[sv]


# Refer SVM.pdf for more clarity
#Validation

for n in range(len(sv_lambda)):
    b += sv_label[n]
    b -= np.sum(sv_lambda * sv_label * K[sv_index[n],sv])
b /= len(sv_lambda)


y_predict = np.zeros(len(test_data))
for i in range(len(test_data)):
    s = 0
    for a, sv_y, sv in zip(sv_lambda, sv_label, sv_fea):
        s += (np.exp(gamma*(-linalg.norm(sv-test_data[i])**2)))*a*sv_y
    y_predict[i] = s
y_predict=np.array(y_predict)+b


y_predict=np.sign(y_predict)

label_test=np.array(label_test)

Accuracy_table=np.ravel(label_test==y_predict)
count=0
for i in range(len(label_test)):
    if(Accuracy_table[i]==True):
        count+=1
        
print('No of Samples for which output is predicted correctly: {}'.format(count/4))
# Out:
#      pcost       dcost       gap    pres   dres
#  0:  1.6493e+02 -4.2285e+03  8e+03  4e-01  5e-15
#  1:  1.3359e+02 -5.4330e+02  7e+02  2e-03  4e-15
#  2: -2.0471e+01 -1.4169e+02  1e+02  2e-04  4e-15
#  3: -4.9398e+01 -8.1350e+01  3e+01  4e-05  3e-15
#  4: -5.9856e+01 -6.8938e+01  9e+00  5e-06  4e-15
#  5: -6.3119e+01 -6.5007e+01  2e+00  7e-07  4e-15
#  6: -6.3906e+01 -6.4013e+01  1e-01  3e-08  5e-15
#  7: -6.3955e+01 -6.3957e+01  2e-03  4e-10  4e-15
#  8: -6.3956e+01 -6.3956e+01  2e-05  4e-12  5e-15
# Optimal solution found.
# No of Samples for which output is predicted correctly: 97.25
