# %%
from libsvm.svmutil import *
import numpy as np
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt
import cvxopt
from cvxopt import matrix,solvers

# %% [markdown]
# # Using LIBSVM

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[5:7] # labels for Binary Clasification # (labels are 4.0 and 9.0)
print(labels)
# Out:
# [4. 9.]

# %%
df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]
df3=df1.Column25
label=np.array(df3)
print(len(label))
label_train=label[0:180]
label_test=label[180:580]
df1=df1.iloc[:,0:10:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:180]
test_data=data[180:580]
# Out:
# 580

# %%
prob = svm_problem(label_train, train_data)

c=[]
Accuracy=[]
max=0
j=0
for i in range(-20,20):
    c.append(i)
    param = svm_parameter('-t 0 -c {} -b 0'.format(2**i))
    m = svm_train(prob, param)
    p_label, p_acc, p_val = svm_predict(label_train, train_data, m) 
    Accuracy.append(p_acc[0])

    if(max<p_acc[0]):
        max=p_acc[0]
        j=i
    
plt.plot(c,Accuracy,label='train')

c=[]
Accuracy=[]
max=0
j=0
for i in range(-20,40):
    c.append(i)
    param = svm_parameter('-t 0 -c {} -b 0'.format(2**i))
    m = svm_train(prob, param)
    p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
    Accuracy.append(p_acc[0])

    if(max<p_acc[0]):
        max=p_acc[0]
        j=i
    
plt.plot(c,Accuracy,label='test')
plt.show()
print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
# Out:
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 53.8889% (97/180) (classification)
# Accuracy = 74.4444% (134/180) (classification)
# Accuracy = 82.7778% (149/180) (classification)
# Accuracy = 83.3333% (150/180) (classification)
# Accuracy = 84.4444% (152/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 85.5556% (154/180) (classification)
# Accuracy = 87.2222% (157/180) (classification)
# Accuracy = 87.2222% (157/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 86.1111% (155/180) (classification)
# Accuracy = 87.2222% (157/180) (classification)
# Accuracy = 86.6667% (156/180) (classification)
# Accuracy = 84.4444% (152/180) (classification)
# Accuracy = 81.1111% (146/180) (classification)
# Accuracy = 55.5556% (100/180) (classification)
# Accuracy = 72.7778% (131/180) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 66.75% (267/400) (classification)
# Accuracy = 74% (296/400) (classification)
# Accuracy = 76.5% (306/400) (classification)
# Accuracy = 77.75% (311/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.5% (318/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 78.25% (313/400) (classification)
# Accuracy = 78.25% (313/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 78% (312/400) (classification)
# Accuracy = 77.75% (311/400) (classification)
# Accuracy = 76.25% (305/400) (classification)
# Accuracy = 79.25% (317/400) (classification)
# Accuracy = 79% (316/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79% (316/400) (classification)
# Accuracy = 49.75% (199/400) (classification)
# Accuracy = 64.25% (257/400) (classification)
# Accuracy = 59.5% (238/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Accuracy = 64% (256/400) (classification)
# Value of coarse log2(c), for maximum accuracy: 0

# %%
c=[]
Accuracy=[]
max=0
j=0
i=-1
while(i<1):
    c.append(2**i)
    param = svm_parameter('-t 0 -c {} -b 0'.format(2**i))
    m = svm_train(prob, param)
#svm_type = m.get_svm_type()
    p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
    Accuracy.append(p_acc[0])
    #print(svm_type)
    #print(m)
    if(max<p_acc[0]):
        max=p_acc[0]
        j=i
    i+=0.001
plt.plot(c,Accuracy)
plt.show()
print('Value of fine log2(c), for maximum accuracy: {}'.format(j))
# Out:
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.5% (318/400) (classification)
# Accuracy = 79.5% (318/400) (classification)
# Accuracy = 79.75% (319/400) (classification)
# Accuracy = 79.5% (318/400) (classification)
# Accuracy = 79.5% (318/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80% (320/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# ...
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.75% (323/400) (classification)
# Accuracy = 80.75% (323/400) (classification)
# Accuracy = 80.75% (323/400) (classification)
# Accuracy = 80.75% (323/400) (classification)
# Accuracy = 80.75% (323/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.75% (323/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.5% (322/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Accuracy = 80.25% (321/400) (classification)
# Value of fine log2(c), for maximum accuracy: 0.8870000000000016

# %% [markdown]
# # Using CVXOPT

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[5:7] # labels for Binary Clasification

# %%
df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]

# %%
df3=df1.Column25
label=np.array(df3)

for i in range(len(label)):
    if(label[i]==4.0):
        label[i]=1.0
    else:
        label[i]=-1.0
        
label_train=label[0:177]
label_test=label[177:577]

# %%
df1=df1.iloc[:,0:10:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:177]
test_data=data[177:577]

N=len(label_train)
X=train_data
y=label_train

K = np.zeros((N,N))

# Generating Kernel Function
for i in range(N):
    for j in range(N):
        K[i,j] = np.dot(X[i], X[j])
        
# Generating P and q
P=cvxopt.matrix(np.outer(y,y) * K)
q = cvxopt.matrix(np.ones(N) * -1)


C=2**(0.88)

#Generating conditions (i.e., o<lambd_i<c)
G1 = np.diag(np.ones(N) * -1)
G2 = np.identity(N)
G = cvxopt.matrix(np.vstack((G1, G2)))

h1 = np.zeros(N)
h2 = np.ones(N) * C
h = cvxopt.matrix(np.hstack((h1, h2)))


#Generating conditions (i.e., sigma())
A=cvxopt.matrix(y, (1,N))
b = cvxopt.matrix(0.0)

solution = cvxopt.solvers.qp(P, q, G, h,A,b)

a = np.ravel(solution['x'])
sv= a>1e-4
sv_index = np.arange(len(a))[sv]
sv_lambda= a[sv]  # Represent lambdas of all support vectors
sv_fea= X[sv]     # Represent all support vectors
sv_label = y[sv]


# Refer SVM.pdf for more clarity
#Validation

for n in range(len(sv_lambda)):
    b += sv_label[n]
    b -= np.sum(sv_lambda * sv_label * K[sv_index[n],sv])
b /= len(sv_lambda)


y_predict = np.zeros(len(test_data))
for i in range(len(test_data)):
    s = 0
    for a, sv_y, sv in zip(sv_lambda, sv_label, sv_fea):
        s += a * sv_y * np.dot(test_data[i], sv)
    y_predict[i] = s
y_predict=np.array(y_predict)+b


y_predict=np.sign(y_predict)

label_test=np.array(label_test)

Accuracy_table=np.ravel(label_test==y_predict)

count=0
for i in range(len(label_test)):
    if(Accuracy_table[i]==True):
        count+=1
        
print('No of Samples for which output is predicted correctly: {}'.format(count/4))
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -1.2008e+02 -9.0068e+02  3e+03  2e+00  4e-14
#  1: -9.3661e+01 -4.7521e+02  5e+02  2e-01  3e-14
#  2: -9.3213e+01 -1.7287e+02  9e+01  3e-02  2e-14
#  3: -1.0564e+02 -1.3096e+02  3e+01  6e-03  3e-14
#  4: -1.1052e+02 -1.2020e+02  1e+01  2e-03  2e-14
#  5: -1.1305e+02 -1.1607e+02  3e+00  4e-04  3e-14
#  6: -1.1382e+02 -1.1486e+02  1e+00  6e-05  3e-14
#  7: -1.1415e+02 -1.1442e+02  3e-01  1e-05  3e-14
#  8: -1.1421e+02 -1.1434e+02  1e-01  3e-06  3e-14
#  9: -1.1426e+02 -1.1427e+02  6e-03  2e-16  3e-14
# 10: -1.1427e+02 -1.1427e+02  1e-04  9e-16  3e-14
# Optimal solution found.
# No of Samples for which output is predicted correctly: 79.25
