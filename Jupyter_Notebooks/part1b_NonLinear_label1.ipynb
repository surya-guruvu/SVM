# %% [markdown]
# # Using LIBSVM

# %%
from libsvm.svmutil import *
import numpy as np
from numpy import linalg
import pandas as pd
import math
import matplotlib
import matplotlib.pyplot as plt
import cvxopt
from cvxopt import matrix,solvers

df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[0:2] # labels for Binary Clasification

df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]

df3=df1.Column25
label=np.array(df3)
label_train=label[0:177]
label_test=label[177:577]

df1=df1.iloc[:,0:10:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:177]
test_data=data[177:577]

prob = svm_problem(label_train, train_data)

Accuracy=[]
max=0
j=0
j1=0
for k in range(-10,10):
    for i in range(-10,10):
        param = svm_parameter('-t 2 -g {} -c {} -b 0'.format(2**k,2**i))
        m = svm_train(prob, param)
        p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
        Accuracy.append(p_acc[0])
        if(max<p_acc[0]):
            max=p_acc[0]
            j=i
            j1=k
    

print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
print('Value of coarse log2(gamma), for maximum accuracy: {}'.format(j1))
print('The percentage of predicted values')
# Out:
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 71.75% (287/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 93.5% (374/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 66.75% (267/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 61.75% (247/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 94% (376/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.5% (378/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.5% (386/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 72.5% (290/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 94.75% (379/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.5% (386/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96.5% (386/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96.5% (386/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 77.75% (311/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 88% (352/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 64.5% (258/400) (classification)
# Accuracy = 88.5% (354/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 60.25% (241/400) (classification)
# Accuracy = 81% (324/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 84.75% (339/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 60.75% (243/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 63.75% (255/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 58.75% (235/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 59.25% (237/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 58% (232/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.75% (231/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Accuracy = 57.5% (230/400) (classification)
# Value of coarse log2(c), for maximum accuracy: 0
# Value of coarse log2(gamma), for maximum accuracy: -3
# The percentage of predicted values

# %%
prob = svm_problem(label_train, train_data)

Accuracy=[]
max=0
j=0
j1=0
k=-4
while(k<-2):
    i=-1
    while(i<1):
        param = svm_parameter('-t 2 -g {} -c {} -b 0'.format(2**k,2**i))
        m = svm_train(prob, param)
        p_label, p_acc, p_val = svm_predict(label_test, test_data, m) 
        Accuracy.append(p_acc[0])
        if(max<p_acc[0]):
            max=p_acc[0]
            j=i
            j1=k
        i+=0.1
    k+=0.1
    

print('Value of coarse log2(c), for maximum accuracy: {}'.format(j))
print('Value of coarse log2(gamma), for maximum accuracy: {}'.format(j1))
print('The percentage of predicted values is equal to {} %'.format(max))
# Out:
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.5% (394/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98.5% (394/400) (classification)
# Accuracy = 98.5% (394/400) (classification)
# Accuracy = 98.5% (394/400) (classification)
# Accuracy = 98.5% (394/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.5% (394/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 98.25% (393/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 98% (392/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.75% (391/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 97.5% (390/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 95.5% (382/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97.25% (389/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.5% (386/400) (classification)
# Accuracy = 96.5% (386/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 97% (388/400) (classification)
# Accuracy = 92.5% (370/400) (classification)
# Accuracy = 94.25% (377/400) (classification)
# Accuracy = 95% (380/400) (classification)
# Accuracy = 95.25% (381/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 95.75% (383/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96% (384/400) (classification)
# Accuracy = 96.25% (385/400) (classification)
# Accuracy = 96.5% (386/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Accuracy = 96.75% (387/400) (classification)
# Value of coarse log2(c), for maximum accuracy: -0.8
# Value of coarse log2(gamma), for maximum accuracy: -3.5999999999999996
# The percentage of predicted values is equal to 98.5 %

# %% [markdown]
# # Using CVXOPT

# %%
df = pd.read_csv('C:/Users/surya/Downloads/2019EE10481/2019EE10481.csv',header = None,prefix='Column') 
labelsAll= df['Column25'].unique() #unique labels
labels=labelsAll[0:2] # labels for Binary Clasification

# %%
df1=df[(df.Column25==labels[0]) | (df.Column25==labels[1])]

# %%
df3=df1.Column25
label=np.array(df3)

for i in range(len(label)):
    if(label[i]==2.0):
        label[i]=1.0
    else:
        label[i]=-1.0
        
label_train=label[0:177]
label_test=label[177:577]

# %%
df1=df1.iloc[:,0:10:1]
data = df1.values #To convert data frame into numpy array
train_data=data[0:177]
test_data=data[177:577]

N=len(label_train)
X=train_data
y=label_train

K = np.zeros((N,N))

gamma=1/(2**3.6)
C=2**(-0.8)

# Generating Kernel Function (Gram-Matrix)
for i in range(N):
    for j in range(N):
        K[i,j] = np.exp((-linalg.norm(X[i]-X[j])**2)*gamma) 
        
# Generating P and q
P=cvxopt.matrix(np.outer(y,y) * K)
q = cvxopt.matrix(np.ones(N) * -1)




#Generating conditions (i.e., o<=lambd_i<=c)
G1 = np.diag(np.ones(N) * -1)
G2 = np.identity(N)
G = cvxopt.matrix(np.vstack((G1, G2)))

h1 = np.zeros(N)
h2 = np.ones(N) * C
h = cvxopt.matrix(np.hstack((h1, h2)))


#Generating conditions (i.e., sigma())
A=cvxopt.matrix(y, (1,N))
b = cvxopt.matrix(0.0)

solution = cvxopt.solvers.qp(P, q, G, h,A,b)

a = np.ravel(solution['x'])
sv= a>1e-4
sv_index = np.arange(len(a))[sv]
sv_lambda= a[sv]  # Represent lambdas of all support vectors
sv_fea= X[sv]     # Represent all support vectors
sv_label = y[sv]


# Refer SVM.pdf for more clarity
#Validation

for n in range(len(sv_lambda)):
    b += sv_label[n]
    b -= np.sum(sv_lambda * sv_label * K[sv_index[n],sv])
b /= len(sv_lambda)


y_predict = np.zeros(len(test_data))
for i in range(len(test_data)):
    s = 0
    for a, sv_y, sv in zip(sv_lambda, sv_label, sv_fea):
        s += (np.exp(gamma*(-linalg.norm(sv-test_data[i])**2)))*a*sv_y
    y_predict[i] = s
y_predict=np.array(y_predict)+b


y_predict=np.sign(y_predict)

label_test=np.array(label_test)

Accuracy_table=np.ravel(label_test==y_predict)
count=0
for i in range(len(label_test)):
    if(Accuracy_table[i]==True):
        count+=1
        
print('No of Samples for which output is predicted correctly: {}'.format(count/4))
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -2.0611e+01 -1.5406e+02  7e+02  3e+00  4e-16
#  1: -1.7050e+01 -1.0145e+02  8e+01  4e-16  4e-16
#  2: -1.9864e+01 -2.9493e+01  1e+01  2e-16  3e-16
#  3: -2.1960e+01 -2.3845e+01  2e+00  2e-16  2e-16
#  4: -2.2486e+01 -2.2749e+01  3e-01  2e-16  2e-16
#  5: -2.2570e+01 -2.2588e+01  2e-02  2e-15  2e-16
#  6: -2.2576e+01 -2.2577e+01  7e-04  3e-15  2e-16
#  7: -2.2577e+01 -2.2577e+01  1e-05  2e-15  2e-16
# Optimal solution found.
# No of Samples for which output is predicted correctly: 98.25
